# %%
import pandas as pd

data = pd.read_csv('raw.csv').sample(n=10000, ignore_index=True, random_state=42)
data
# Out:
#       Unnamed: 0                                                url  \
# 0         536448             http://37.49.226.178/deusbins/deus.sh4
# 1          40630  medical-dictionary.thefreedictionary.com/Galt+...
# 2         630496                         www.jscape.com/sshfactory/
# 3         426724  http://www.wsnc.org.au/component/jcalpro/view/983
# 4         184034  virtualtourist.com/travel/North_America/Canada...
# ...          ...                                                ...
# 9995      209786  martindale.com/McCarthy-Tetrault-LLP/law-firm-...
# 9996      363875  gediflora.be/EN/producten-detailfiche.asp?line...
# 9997      416397                                    music.yale.edu/
# 9998      347074  http://nonstopwebmarketing.com.au/web-services...
# 9999      124093          http://www.fenx365.com/LeaveComments.aspx
#
#             type  use_of_ip  abnormal_url  google_index  count.  count-www  \
# 0        malware          1             1             1       4          0
# 1         benign          0             0             1       2          0
# 2       phishing          0             0             1       2          1
# 3     defacement          0             1             1       3          1
# 4         benign          0             0             1       2          0
# ...          ...        ...           ...           ...     ...        ...
# 9995      benign          0             0             1       2          0
# 9996      benign          0             0             1       2          0
# 9997      benign          0             0             1       2          0
# 9998  defacement          0             1             1       2          0
# 9999  defacement          0             1             1       3          1
#
#       count@  count_dir  ...  count?  count-  count=  url_length  \
# 0          0          2  ...       0       0       0          38
# 1          0          1  ...       0       1       0          54
# 2          0          2  ...       0       0       0          26
# 3          0          4  ...       0       0       0          49
# 4          0          6  ...       0       5       0         121
# ...      ...        ...  ...     ...     ...     ...         ...
# 9995       0          2  ...       0       4       0          56
# 9996       0          2  ...       1       2       2          77
# 9997       0          1  ...       0       0       0          15
# 9998       0          3  ...       1       4       1          93
# 9999       0          1  ...       0       0       0          41
#
#       hostname_length  fd_length  tld_length  count_digits  count_letters  \
# 0                  13          8          -1            11             18
# 1                   0         13          -1             0             49
# 2                   0         10          -1             0             22
# 3                  15          9           6             3             36
# 4                   0          6          -1             7             98
# ...               ...        ...         ...           ...            ...
# 9995                0         21          -1             6             42
# 9996                0          2          -1             2             64
# 9997                0          0          -1             0             12
# 9998               26         12           6             0             79
# 9999               15         18           3             3             31
#
#       type_code
# 0             2
# 1             0
# 2             3
# 3             1
# 4             0
# ...         ...
# 9995          0
# 9996          0
# 9997          0
# 9998          1
# 9999          1
#
# [10000 rows x 26 columns]

# %%
data['type_binary'] = data['type'].apply(lambda x: 0 if x == 'benign' else 1)

data_cleaned = data.drop(['Unnamed: 0', 'type'], axis=1)
data_cleaned
# Out:
#                                                     url  use_of_ip  \
# 0                http://37.49.226.178/deusbins/deus.sh4          1
# 1     medical-dictionary.thefreedictionary.com/Galt+...          0
# 2                            www.jscape.com/sshfactory/          0
# 3     http://www.wsnc.org.au/component/jcalpro/view/983          0
# 4     virtualtourist.com/travel/North_America/Canada...          0
# ...                                                 ...        ...
# 9995  martindale.com/McCarthy-Tetrault-LLP/law-firm-...          0
# 9996  gediflora.be/EN/producten-detailfiche.asp?line...          0
# 9997                                    music.yale.edu/          0
# 9998  http://nonstopwebmarketing.com.au/web-services...          0
# 9999          http://www.fenx365.com/LeaveComments.aspx          0
#
#       abnormal_url  google_index  count.  count-www  count@  count_dir  \
# 0                1             1       4          0       0          2
# 1                0             1       2          0       0          1
# 2                0             1       2          1       0          2
# 3                1             1       3          1       0          4
# 4                0             1       2          0       0          6
# ...            ...           ...     ...        ...     ...        ...
# 9995             0             1       2          0       0          2
# 9996             0             1       2          0       0          2
# 9997             0             1       2          0       0          1
# 9998             1             1       2          0       0          3
# 9999             1             1       3          1       0          1
#
#       count_embed_domain  sus_url  ...  count-  count=  url_length  \
# 0                      0        0  ...       0       0          38
# 1                      0        1  ...       1       0          54
# 2                      0        0  ...       0       0          26
# 3                      0        0  ...       0       0          49
# 4                      0        0  ...       5       0         121
# ...                  ...      ...  ...     ...     ...         ...
# 9995                   0        0  ...       4       0          56
# 9996                   0        0  ...       2       2          77
# 9997                   0        0  ...       0       0          15
# 9998                   0        1  ...       4       1          93
# 9999                   0        0  ...       0       0          41
#
#       hostname_length  fd_length  tld_length  count_digits  count_letters  \
# 0                  13          8          -1            11             18
# 1                   0         13          -1             0             49
# 2                   0         10          -1             0             22
# 3                  15          9           6             3             36
# 4                   0          6          -1             7             98
# ...               ...        ...         ...           ...            ...
# 9995                0         21          -1             6             42
# 9996                0          2          -1             2             64
# 9997                0          0          -1             0             12
# 9998               26         12           6             0             79
# 9999               15         18           3             3             31
#
#       type_code  type_binary
# 0             2            1
# 1             0            0
# 2             3            1
# 3             1            1
# 4             0            0
# ...         ...          ...
# 9995          0            0
# 9996          0            0
# 9997          0            0
# 9998          1            1
# 9999          1            1
#
# [10000 rows x 25 columns]

# %%
data_cleaned['type_binary'].value_counts()
# Out:
# type_binary
# 0    6624
# 1    3376
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from torch.utils.data import DataLoader
import torch

# %%
data_cleaned['label'] = data_cleaned['type_binary'].astype('category').cat.codes

# Split data into training and validation
train_data, val_data = train_test_split(data_cleaned, test_size=0.2, random_state=42)

# Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
def prepare_data(data, tokenizer, max_len=256):
    tokens = tokenizer.batch_encode_plus(
        data['url'].tolist(),
        max_length=max_len,
        padding='max_length',
        truncation=True,
        return_tensors='pt'
    )
    return {
        'input_ids': tokens['input_ids'],
        'attention_mask': tokens['attention_mask'],
        'labels': torch.tensor(data['label'].values, dtype=torch.long)
    }

# %%
def create_data_loader(dataset, batch_size):
    return DataLoader(
        [{key: value[i] for key, value in dataset.items()} for i in range(len(dataset['labels']))], 
        batch_size=batch_size, 
        shuffle=True
    )

# %%
train_data = prepare_data(train_data, tokenizer)
val_data = prepare_data(val_data, tokenizer)

train_loader = create_data_loader(train_data, 8)
val_loader = create_data_loader(val_data, 8)

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=data_cleaned['label'].nunique())
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
optimizer = AdamW(model.parameters(), lr=0.000001)
# Out:
# c:\Users\ivomeister\anaconda3\Lib\site-packages\transformers\optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight('balanced', classes=np.unique(data_cleaned['label'] ), y=data_cleaned['label'])
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

# %%
import torch.nn
from tqdm import tqdm
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Parameter for Early Stopping
best_accuracy = 0

# Loss function
loss_fn = torch.nn.CrossEntropyLoss()

epochs = 5

for epoch in range(epochs):
    print(f'Starting epoch {epoch+1}/{epochs}')
    model.train()
    for batch in tqdm(train_loader):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        
        # Reset gradients
        optimizer.zero_grad()
        
        # Get model outputs
        outputs = model(input_ids, attention_mask=attention_mask)
        
        # Compute loss
        loss = loss_fn(outputs.logits, labels)
        
        # Backpropagate
        loss.backward()
        optimizer.step()

    # Validation phase
    model.eval()
    total_val_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            
            outputs = model(input_ids, attention_mask=attention_mask)
            loss = loss_fn(outputs.logits, labels)
            total_val_loss += loss.item()

            # Get predictions
            preds = torch.argmax(outputs.logits, dim=-1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_val_loss = total_val_loss / len(val_loader)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')
    cm = confusion_matrix(all_labels, all_preds)

    print(f'Epoch {epoch+1}, Validation Loss: {avg_val_loss:.4f}')
    print(f'Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}')
    
    # Plot confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - Epoch {epoch+1}')
    plt.show()

    # Early stopping logic
    if accuracy > best_accuracy:
        best_accuracy = accuracy
    else:
        print("Early stopping activated.")
        break
# Out:
# Starting epoch 1/5
# 100%|██████████| 1000/1000 [11:39<00:00,  1.43it/s]
# Epoch 1, Validation Loss: 0.2025
# Accuracy: 0.9345, Precision: 0.9380, Recall: 0.9345, F1 Score: 0.9351
# Starting epoch 2/5
# 100%|██████████| 1000/1000 [11:43<00:00,  1.42it/s]
# Epoch 2, Validation Loss: 0.1304
# Accuracy: 0.9585, Precision: 0.9589, Recall: 0.9585, F1 Score: 0.9586
# Starting epoch 3/5
# 100%|██████████| 1000/1000 [11:43<00:00,  1.42it/s]
# Epoch 3, Validation Loss: 0.1124
# Accuracy: 0.9620, Precision: 0.9627, Recall: 0.9620, F1 Score: 0.9622
# Starting epoch 4/5
# 100%|██████████| 1000/1000 [11:44<00:00,  1.42it/s]
# Epoch 4, Validation Loss: 0.1103
# Accuracy: 0.9635, Precision: 0.9645, Recall: 0.9635, F1 Score: 0.9637
# Starting epoch 5/5
# 100%|██████████| 1000/1000 [11:43<00:00,  1.42it/s]
# Epoch 5, Validation Loss: 0.0871
# Accuracy: 0.9760, Precision: 0.9762, Recall: 0.9760, F1 Score: 0.9760
